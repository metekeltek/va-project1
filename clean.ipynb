# %%
import pandas as pd

com=pd.read_csv("data/bgg_Gameitems.csv")
reco=pd.read_csv("data/recommendations-2021-12-31.csv")

com.isnull().sum()
# Out:
# bgg_id                      0
# name                        0
# year                     9685
# game_type               88074
# artist                  66032
# publisher                  52
# min_players              1938
# max_players              5456
# min_players_rec          1938
# max_players_rec          5456
# min_players_best         1938
# max_players_best         5456
# min_age                 23263
# min_age_rec            112778
# min_time                22562
# max_time                22562
# category                 2214
# mechanic                16767
# cooperative            107550
# compilation            112989
# compilation_of         112989
# family                  34859
# implementation         108039
# integration            109784
# rank                    89425
# num_votes               27722
# avg_rating              27722
# stddev_rating           45407
# bayes_rating            88970
# complexity              65614
# language_dependency    113050
# ...

# %%
com.isnull().sum() < 25000
# Out:
# bgg_id                  True
# name                    True
# year                    True
# game_type              False
# artist                 False
# publisher               True
# min_players             True
# max_players             True
# min_players_rec         True
# max_players_rec         True
# min_players_best        True
# max_players_best        True
# min_age                 True
# min_age_rec            False
# min_time                True
# max_time                True
# category                True
# mechanic                True
# cooperative            False
# compilation            False
# compilation_of         False
# family                 False
# implementation         False
# integration            False
# rank                   False
# num_votes              False
# avg_rating             False
# stddev_rating          False
# bayes_rating           False
# complexity             False
# language_dependency    False
# bga_id                 False
# ...

# %%
print("------")
publisher = com['publisher']
print(len(publisher))
p = com['publisher'].unique()
print(p)
print(len(p))

com.head()
# Out:
# ------
# 113904
# ['Hans im Glück,Moskito Spiele,Ediciones MasQueOca,Portal Games,Spielworxx,sternenschimmermeer,Stronghold Games,Valley Games, Inc.,YOKA Games'
#  'E.S. Lowe,Milton Bradley'
#  'Fantasy Flight Games,Hans im Glück,999 Games,ABACUSSPIELE,Astrel Games,Ceilikan Jogos,Descartes Editeur,Edge Entertainment,Galakta,Hobby Japan,Korea Boardgames Co., Ltd.,Lacerta,Lautapelit.fi,Rio Grande Games,Skandinavisk Spil Kompagni,Smart Ltd,Wargames Club Publishing'
#  ... 'Singa Jogos' 'Repos Production,Hobby Japan' 'Pb box ehf.']
# 35998
#    bgg_id            name    year      game_type  \
# 0       1      Die Macher  1986.0  Strategy Game
# 1       2    Dragonmaster  1981.0  Strategy Game
# 2       3         Samurai  1998.0  Strategy Game
# 3       4  Tal der Könige  1992.0  Strategy Game
# 4       5         Acquire  1964.0  Strategy Game
#
#                               artist  \
# 0  Marcus Gschwendtner,Harald Lieske
# 1                         Bob Pepper
# ...
